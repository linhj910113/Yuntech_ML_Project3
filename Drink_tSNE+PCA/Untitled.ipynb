# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn import manifold, datasets
from sklearn.preprocessing import MinMaxScaler

# %%
x = pd.read_csv('data.csv',encoding='utf-8')

# %%
x
# Out:
#   Class       Drink  Rank    m    s  Count
# 0     A        Coke     7  100  200    200
# 1     B       Pepsi     6  200   10    100
# 2     C         7Up     5  200   10    100
# 3     D      Sprite     4  400  100    200
# 4     E       Latte     3  800   10    100
# 5     F    Espresso     2  800   10    100
# 6     G  Cappuccino     1  900  400    200

# %%
drink_name= ['coke','pepsi','7up','sprite','latte','espresso','cappuccino']

# %%
df = pd.DataFrame()

for index,row in x.iterrows():
    Class=row['Class']
    drink=row['Drink']
    rank=row['Rank']
    m=row['m']
    s=row['s']
    count=row['Count']
    
    data=np.random.normal(m,s,count)
    
    for d in data :
        d = [[drink,rank,d]]
        print(d)
        df = df.append(d)

df.reset_index(inplace=True)
df=df.drop(['index'], axis=1)
df.columns=['drink','rank','data']
# Out:
# [['Coke', 7, 455.928539828487]]
# [['Coke', 7, 319.8394275114006]]
# [['Coke', 7, 94.57179464927513]]
# [['Coke', 7, -230.30482909017235]]
# [['Coke', 7, -4.664819670931024]]
# [['Coke', 7, 314.36166387241167]]
# [['Coke', 7, 3.2948081926159034]]
# [['Coke', 7, 544.8877543796]]
# [['Coke', 7, -234.91113731093856]]
# [['Coke', 7, 184.78042559313354]]
# [['Coke', 7, 135.93772999876197]]
# [['Coke', 7, 95.96659240883741]]
# [['Coke', 7, 230.81666377138973]]
# [['Coke', 7, 184.37881887518805]]
# [['Coke', 7, 14.617734487159709]]
# [['Coke', 7, -352.3483750706389]]
# [['Coke', 7, 397.3482554072154]]
# [['Coke', 7, 153.70557542428304]]
# [['Coke', 7, -383.3138627208233]]
# [['Coke', 7, 16.502133609456365]]
# [['Coke', 7, 285.7972941148721]]
# [['Coke', 7, 109.29288860521363]]
# [['Coke', 7, 351.157487136212]]
# [['Coke', 7, 163.17118619864337]]
# [['Coke', 7, 288.730211140414]]
# [['Coke', 7, 143.04769214875904]]
# [['Coke', 7, 267.13298139722383]]
# [['Coke', 7, -93.37598514872363]]
# ...

# %%
# def plot_2DMDS(data):
#     marker = ['.','<','+','*','v','>','o']
#     color=['r','g','b','c','m','y','black']
#     fig = plt.figure()
#     plt.figure(figsize=(12,8))
#     ax = fig.gca(projection='3d')
    
#     for i in range(0,7):
#         data_x = data[data['rank']==i].x
#         data_y = data[data['rank']==i].y
#         data_z = data[data['rank']==i].z
#         ax.scatter(data_x, data_y, data_z)
#     plt.legend(drink_name)
#     plt.show()
    
    
def plot_2DMDS(data):
    marker = ['.','<','+','*','v','>','o']
    color=['r','g','b','c','m','y','black']
    plt.figure(figsize=(12,8))
    for i in range(0,7):
        data_x = data[data['rank']==i+1].x
        data_y = data[data['rank']==i+1].y
        plt.scatter(x=data_x,y=data_y,
                    color=color[i],
                    alpha=0.5
                   )
    plt.legend(drink_name)
    plt.show()

# %%
scaler = MinMaxScaler()

#訓練集
df['data'] = scaler.fit_transform(df[['data']])
# df = pd.DataFrame(train1,columns=df.columns)

df
# Out:
#           drink  rank      data
# 0          Coke     7  0.355802
# 1          Coke     7  0.299717
# 2          Coke     7  0.206880
# 3          Coke     7  0.072992
# 4          Coke     7  0.165982
# ..          ...   ...       ...
# 995  Cappuccino     1  0.629888
# 996  Cappuccino     1  0.400273
# 997  Cappuccino     1  0.264768
# 998  Cappuccino     1  0.156006
# 999  Cappuccino     1  0.486751
#
# [1000 rows x 3 columns]

# %%
df_1=df[['drink','rank','data']]

# %%
df_1
# Out:
#           drink  rank      data
# 0          Coke     7  0.355802
# 1          Coke     7  0.299717
# 2          Coke     7  0.206880
# 3          Coke     7  0.072992
# 4          Coke     7  0.165982
# ..          ...   ...       ...
# 995  Cappuccino     1  0.629888
# 996  Cappuccino     1  0.400273
# 997  Cappuccino     1  0.264768
# 998  Cappuccino     1  0.156006
# 999  Cappuccino     1  0.486751
#
# [1000 rows x 3 columns]

# %%
df1_onehot = pd.get_dummies(df_1)

# %%
df1_onehot
# Out:
#      rank      data  drink_7Up  drink_Cappuccino  drink_Coke  drink_Espresso  \
# 0       7  0.355802          0                 0           1               0
# 1       7  0.299717          0                 0           1               0
# 2       7  0.206880          0                 0           1               0
# 3       7  0.072992          0                 0           1               0
# 4       7  0.165982          0                 0           1               0
# ..    ...       ...        ...               ...         ...             ...
# 995     1  0.629888          0                 1           0               0
# 996     1  0.400273          0                 1           0               0
# 997     1  0.264768          0                 1           0               0
# 998     1  0.156006          0                 1           0               0
# 999     1  0.486751          0                 1           0               0
#
#      drink_Latte  drink_Pepsi  drink_Sprite
# ...

# %%
X_tsne = manifold.TSNE(n_components=2, init='pca', random_state=5, verbose=1).fit_transform(df1_onehot)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 1000 samples in 0.002s...
# [t-SNE] Computed neighbors for 1000 samples in 0.015s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1000
# [t-SNE] Mean sigma: 0.002105
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 44.709274
# [t-SNE] KL divergence after 1000 iterations: 0.112354

# %%
X_tsne
# Out:
# array([[-43.20587  , -24.485544 ],
#        [-44.831326 , -21.925226 ],
#        [-53.82435  ,  -6.5816083],
#        ...,
#        [ 60.130836 ,   8.541796 ],
#        [ 60.638893 ,   9.565007 ],
#        [ 56.33465  ,  -3.2977192]], dtype=float32)

# %%
df1_new=pd.DataFrame()

for i in range(df_1.shape[0]):
    data=[[df_1['rank'][i],X_tsne[i][0],X_tsne[i][1]]]
    df1_new = df1_new.append(data)
df1_new.columns=['rank','x','y']

# %%
df1_new
# Out:
#     rank          x          y
# 0      7 -43.205872 -24.485544
# 0      7 -44.831326 -21.925226
# 0      7 -53.824348  -6.581608
# 0      7 -59.666737   4.976408
# 0      7 -56.842533  -0.724287
# ..   ...        ...        ...
# 0      1  51.715080 -15.207982
# 0      1  58.327621   2.746380
# 0      1  60.130836   8.541796
# 0      1  60.638893   9.565007
# 0      1  56.334648  -3.297719
#
# [1000 rows x 3 columns]

# %%
plot_2DMDS(df1_new)

# %%
df_2=df[['drink','data']]

# %%
df_2
# Out:
#           drink      data
# 0          Coke  0.355802
# 1          Coke  0.299717
# 2          Coke  0.206880
# 3          Coke  0.072992
# 4          Coke  0.165982
# ..          ...       ...
# 995  Cappuccino  0.629888
# 996  Cappuccino  0.400273
# 997  Cappuccino  0.264768
# 998  Cappuccino  0.156006
# 999  Cappuccino  0.486751
#
# [1000 rows x 2 columns]

# %%
df2_onehot = pd.get_dummies(df_2)
df2_onehot
# Out:
#          data  drink_7Up  drink_Cappuccino  drink_Coke  drink_Espresso  \
# 0    0.355802          0                 0           1               0
# 1    0.299717          0                 0           1               0
# 2    0.206880          0                 0           1               0
# 3    0.072992          0                 0           1               0
# 4    0.165982          0                 0           1               0
# ..        ...        ...               ...         ...             ...
# 995  0.629888          0                 1           0               0
# 996  0.400273          0                 1           0               0
# 997  0.264768          0                 1           0               0
# 998  0.156006          0                 1           0               0
# 999  0.486751          0                 1           0               0
#
#      drink_Latte  drink_Pepsi  drink_Sprite
# 0              0            0             0
# ...

# %%
X_tsne = manifold.TSNE(n_components=2, init='pca', random_state=5, verbose=1).fit_transform(df2_onehot)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 1000 samples in 0.002s...
# [t-SNE] Computed neighbors for 1000 samples in 0.015s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1000
# [t-SNE] Mean sigma: 0.002105
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 44.651974
# [t-SNE] KL divergence after 1000 iterations: 0.113943

# %%
X_tsne
# Out:
# array([[ -2.8642592, -42.18804  ],
#        [ -4.9511805, -40.171936 ],
#        [-18.042732 , -29.007225 ],
#        ...,
#        [ 11.702689 , -27.582243 ],
#        [ 11.026381 , -28.471888 ],
#        [ 22.006248 , -21.78503  ]], dtype=float32)

# %%
df2_new=pd.DataFrame()

for i in range(df.shape[0]):
    data=[[df['rank'][i],X_tsne[i][0],X_tsne[i][1]]]
    df2_new = df2_new.append(data)
df2_new.columns=['rank','x','y']

# %%
df2_new
# df_new.to_csv("df_new.csv")
# Out:
#     rank          x          y
# 0      7  -2.864259 -42.188042
# 0      7  -4.951180 -40.171936
# 0      7 -18.042732 -29.007225
# 0      7 -28.624792 -22.498133
# 0      7 -23.400770 -25.562855
# ..   ...        ...        ...
# 0      1  32.112202 -14.853498
# 0      1  16.845167 -24.914211
# 0      1  11.702689 -27.582243
# 0      1  11.026381 -28.471888
# 0      1  22.006248 -21.785030
#
# [1000 rows x 3 columns]

# %%
plot_2DMDS(df2_new)
